# %% [markdown]
# # BDAS

# %%
import findspark
findspark.init('/home/ubuntu/spark-2.1.1-bin-hadoop2.7')
import pyspark
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_1 = pd.read_csv('ShanghaiPM20100101_20151231_1.csv')
df_2 = pd.read_csv('ShanghaiPM20100101_20151231_2.csv')

pm_df=df_1.append(df_2)

# %%
pm_df.head()
# Out:
#    No  year  month  day  hour  season  PM_Jingan  PM_US Post  PM_Xuhui  DEWP  \
# 0   1  2011     12   28    18       4        NaN        36.0       NaN   4.0
# 1   2  2011     12   28    19       4        NaN        41.0       NaN   4.0
# 2   3  2011     12   28    20       4        NaN        44.0       NaN   5.0
# 3   4  2011     12   28    21       4        NaN        40.0       NaN   5.0
# 4   5  2011     12   28    22       4        NaN        25.0       NaN   6.0
#
#     HUMI    PRES  TEMP cbwd   Iws  precipitation  Iprec
# 0  62.00  1027.1  11.0   NE   8.0            0.0    0.0
# 1  62.00  1027.1  11.0   NE   9.0            0.0    0.0
# 2  71.07  1028.1  10.0   NE  11.0            0.0    0.0
# 3  71.07  1028.1  10.0   NE  13.0            0.0    0.0
# 4  76.18  1028.1  10.0   NE  15.0            0.0    0.0

# %%
pm_df.tail()
# Out:
#           No  year  month  day  hour  season  PM_Jingan  PM_US Post  PM_Xuhui  \
# 23137  35138  2015     12   31    19       4       86.0        82.0      90.0
# 23138  35139  2015     12   31    20       4       83.0        93.0      86.0
# 23139  35140  2015     12   31    21       4       85.0        90.0      95.0
# 23140  35141  2015     12   31    22       4       83.0        86.0      92.0
# 23141  35142  2015     12   31    23       4        NaN        77.0       NaN
#
#        DEWP   HUMI    PRES  TEMP cbwd   Iws  precipitation  Iprec
# 23137  -1.0  65.13  1035.0   5.0   NE  15.0            0.0    0.0
# 23138   1.0  70.27  1035.0   6.0   NE  19.0            0.0    0.0
# 23139   1.0  70.27  1036.0   6.0   NE  22.0            0.0    0.0
# 23140   0.0  70.06  1035.0   5.0   NE  25.0            0.0    0.0
# 23141   0.0  70.06  1035.0   5.0   NE  27.0            0.0    0.0

# %%
print(pm_df.columns)
# Out:
# Index(['No', 'year', 'month', 'day', 'hour', 'season', 'PM_Jingan',
#        'PM_US Post', 'PM_Xuhui', 'DEWP', 'HUMI', 'PRES', 'TEMP', 'cbwd', 'Iws',
#        'precipitation', 'Iprec'],
#       dtype='object')

# %%
print(pm_df.shape)
# Out:
# (35142, 17)

# %%
print(pm_df.dtypes)
# Out:
# No                 int64
# year               int64
# month              int64
# day                int64
# hour               int64
# season             int64
# PM_Jingan        float64
# PM_US Post       float64
# PM_Xuhui         float64
# DEWP             float64
# HUMI             float64
# PRES             float64
# TEMP             float64
# cbwd              object
# Iws              float64
# precipitation    float64
# Iprec            float64
# dtype: object

# %%
plt.hist(pm_df["PM_US Post"].dropna())
# Out:
# (array([2.688e+04, 5.855e+03, 1.036e+03, 2.110e+02, 3.000e+01, 1.400e+01,
#         8.000e+00, 2.000e+00, 2.000e+00, 1.000e+00]),
#  array([  1. ,  73.9, 146.8, 219.7, 292.6, 365.5, 438.4, 511.3, 584.2,
#         657.1, 730. ]),
#  <a list of 10 Patch objects>)

# %%
pm_df.corr()["PM_US Post"]
# Out:
# No              -0.043969
# year            -0.030007
# month           -0.058360
# day             -0.019010
# hour             0.017788
# season           0.194385
# PM_Jingan        0.960529
# PM_US Post       1.000000
# PM_Xuhui         0.948877
# DEWP            -0.331743
# HUMI            -0.088029
# PRES             0.263330
# TEMP            -0.322774
# Iws             -0.195162
# precipitation   -0.072639
# Iprec           -0.097102
# Name: PM_US Post, dtype: float64

# %%
pm_df.mean()
# Out:
# No               17571.500000
# year              2013.493427
# month                6.535086
# day                 15.760970
# hour                11.501537
# season               2.494793
# PM_Jingan           57.395992
# PM_US Post          52.910544
# PM_Xuhui            57.678987
# DEWP                11.444916
# HUMI                69.898376
# PRES              1015.887170
# TEMP                17.558983
# Iws                 49.437361
# precipitation        0.150761
# Iprec                1.044128
# dtype: float64

# %%
pm_df.std()
# Out:
# No               10144.765916
# year                 1.123287
# month                3.454552
# day                  8.815626
# hour                 6.922729
# season               1.118114
# PM_Jingan           47.616179
# PM_US Post          42.576138
# PM_Xuhui            48.412620
# DEWP                 9.665203
# HUMI                17.799459
# PRES                 9.012046
# TEMP                 9.182528
# Iws                 71.626221
# precipitation        1.084472
# Iprec                7.520179
# dtype: float64

# %%
pm_df.skew()
# Out:
# No                0.000000
# year             -0.008541
# month            -0.010938
# day               0.005283
# hour             -0.000250
# season            0.007545
# PM_Jingan         2.594016
# PM_US Post        2.575156
# PM_Xuhui          2.677977
# DEWP             -0.312592
# HUMI             -0.618855
# PRES              0.070742
# TEMP             -0.096627
# Iws               2.836691
# precipitation    20.697375
# Iprec            17.135168
# dtype: float64

# %%
plt.scatter(pm_df["PM_US Post"],pm_df["PRES"],label="scatter_plot",marker="*")
plt.xlabel('PM_US Post')
plt.ylabel('PRES')
plt.title('PM2.5 VS PRES')
plt.legend()

# %%
plt.ylabel('PM2.5')
plt.xlabel('DEWP') 
plt.title('The relation between PM2.5 and DEWP and TEMP') 
plt.plot(pm_df["DEWP"],pm_df["PM_US Post"],label = 'DEWP')
#plt.plot(pm_df["TEMP"],pm_df["PM_US Post"],label = 'TEMP')
#plt.legend()
plt.show()

# %%
sns.jointplot(x="DEWP", y="PM_US Post", data=pm_df)

# %%
sns.regplot(x="DEWP",y="PM_US Post", data=pm_df,ci=None)

# %%
sns.jointplot(x="DEWP", y="PM_US Post", data=pm_df, kind="kde")

# %%
sns.relplot(x="TEMP", y="PM_US Post", kind="line", data=pm_df)

# %%
sns.catplot(x="cbwd", y="PM_US Post", data=pm_df)

# %%
sns.catplot(x="season", y="PM_US Post", data=pm_df)

# %%
sns.catplot(x="cbwd", y="PM_US Post", kind="box", data=pm_df)

# %%
sns.pairplot(pm_df.dropna(), vars=["PM_US Post", "DEWP", "PRES" ,"TEMP", "HUMI", "Iws"])

# %%
pm_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35142.000000  35142.000000  35142.000000  35142.000000  35142.000000
# mean   17571.500000   2013.493427      6.535086     15.760970     11.501537
# std    10144.765916      1.123287      3.454552      8.815626      6.922729
# min        1.000000   2011.000000      1.000000      1.000000      0.000000
# 25%     8786.250000   2012.000000      4.000000      8.000000      6.000000
# 50%    17571.500000   2013.000000      7.000000     16.000000     12.000000
# 75%    26356.750000   2014.000000     10.000000     23.000000     18.000000
# max    35142.000000   2015.000000     12.000000     31.000000     23.000000
#
#              season     PM_Jingan    PM_US Post      PM_Xuhui          DEWP  \
# count  35142.000000  24700.000000  34039.000000  25189.000000  35137.000000
# mean       2.494793     57.395992     52.910544     57.678987     11.444916
# std        1.118114     47.616179     42.576138     48.412620      9.665203
# min        1.000000      1.000000      1.000000      1.000000    -17.000000
# 25%        1.000000     26.000000     26.000000     26.000000      3.000000
# 50%        2.000000     44.000000     41.000000     43.000000     12.000000
# 75%        3.000000     73.000000     67.000000     73.000000     20.000000
# max        4.000000    635.000000    730.000000    636.000000     28.000000
#
#                HUMI          PRES          TEMP           Iws  precipitation  \
# count  35137.000000  35122.000000  35137.000000  35138.000000   32870.000000
# mean      69.898376   1015.887170     17.558983     49.437361       0.150761
# std       17.799459      9.012046      9.182528     71.626221       1.084472
# min       13.090000    990.000000     -4.000000      0.000000       0.000000
# 25%       58.170000   1008.000000     10.000000      6.000000       0.000000
# 50%       72.960000   1016.000000     19.000000     20.000000       0.000000
# 75%       83.600000   1023.000000     25.000000     62.000000       0.000000
# max      100.000000   1040.000000     41.000000    691.000000      61.600000
#
#               Iprec
# count  32870.000000
# mean       1.044128
# std        7.520179
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      226.400000

# %%
pm_df.isnull().any()
# Out:
# No               False
# year             False
# month            False
# day              False
# hour             False
# season           False
# PM_Jingan         True
# PM_US Post        True
# PM_Xuhui          True
# DEWP              True
# HUMI              True
# PRES              True
# TEMP              True
# cbwd             False
# Iws               True
# precipitation     True
# Iprec             True
# dtype: bool

# %%
pm_df.isnull().apply(pd.value_counts)
# Out:
#             No     year    month      day     hour   season  PM_Jingan  \
# False  35142.0  35142.0  35142.0  35142.0  35142.0  35142.0      24700
# True       NaN      NaN      NaN      NaN      NaN      NaN      10442
#
#        PM_US Post  PM_Xuhui   DEWP   HUMI   PRES   TEMP     cbwd    Iws  \
# False       34039     25189  35137  35137  35122  35137  35142.0  35138
# True         1103      9953      5      5     20      5      NaN      4
#
#        precipitation  Iprec
# False          32870  32870
# True            2272   2272

# %%
pm_plt = pm_df.copy()
del pm_plt['No']
del pm_plt['year']

plt.figure() 
p=pm_plt.boxplot(return_type='dict') 
x=p['fliers'][0].get_xdata()
y=p['fliers'][0].get_ydata()
y.sort()
for i in range(len(x)):
    if i>0:
        plt.annotate(y[i],xy=(x[i],y[i]),xytext=(x[i]+0.05-0.8/(y[i]-y[i-1]),y[i]))
    else:
        plt.annotate(y[i],xy=(x[i],y[i]),xytext=(x[i]+0.08,y[i]))
plt.show()

# %%
del pm_df['PM_Jingan']
del pm_df['PM_Xuhui']
del pm_df['No']
pm_df.head()
# Out:
#    year  month  day  hour  season  PM_US Post  DEWP   HUMI    PRES  TEMP cbwd  \
# 0  2011     12   28    18       4        36.0   4.0  62.00  1027.1  11.0   NE
# 1  2011     12   28    19       4        41.0   4.0  62.00  1027.1  11.0   NE
# 2  2011     12   28    20       4        44.0   5.0  71.07  1028.1  10.0   NE
# 3  2011     12   28    21       4        40.0   5.0  71.07  1028.1  10.0   NE
# 4  2011     12   28    22       4        25.0   6.0  76.18  1028.1  10.0   NE
#
#     Iws  precipitation  Iprec
# 0   8.0            0.0    0.0
# 1   9.0            0.0    0.0
# 2  11.0            0.0    0.0
# 3  13.0            0.0    0.0
# 4  15.0            0.0    0.0

# %%
mean=pm_df.mean()
pm_df.fillna(mean, inplace=True)
pm_df.isnull().apply(pd.value_counts)
# Out:
#         year  month    day   hour  season  PM_US Post   DEWP   HUMI   PRES  \
# False  35142  35142  35142  35142   35142       35142  35142  35142  35142
#
#         TEMP   cbwd    Iws  precipitation  Iprec
# False  35142  35142  35142          35142  35142

# %%
periods = pd.PeriodIndex(year=pm_df["year"], month=pm_df["month"], day=pm_df["day"] ,freq="D")

pm_df = pm_df.set_index(periods)

pm_df.head()
# Out:
#             year  month  day  hour  season  PM_US Post  DEWP   HUMI    PRES  \
# 2011-12-28  2011     12   28    18       4        36.0   4.0  62.00  1027.1
# 2011-12-28  2011     12   28    19       4        41.0   4.0  62.00  1027.1
# 2011-12-28  2011     12   28    20       4        44.0   5.0  71.07  1028.1
# 2011-12-28  2011     12   28    21       4        40.0   5.0  71.07  1028.1
# 2011-12-28  2011     12   28    22       4        25.0   6.0  76.18  1028.1
#
#             TEMP cbwd   Iws  precipitation  Iprec
# 2011-12-28  11.0   NE   8.0            0.0    0.0
# 2011-12-28  11.0   NE   9.0            0.0    0.0
# 2011-12-28  10.0   NE  11.0            0.0    0.0
# 2011-12-28  10.0   NE  13.0            0.0    0.0
# 2011-12-28  10.0   NE  15.0            0.0    0.0

# %%
pm_df['day_or_night'] = np.where((pm_df['hour']>=6) & (pm_df['hour']<=18),1,0)
pm_df.head(10)
# Out:
#             year  month  day  hour  season  PM_US Post  DEWP   HUMI    PRES  \
# 2011-12-28  2011     12   28    18       4        36.0   4.0  62.00  1027.1
# 2011-12-28  2011     12   28    19       4        41.0   4.0  62.00  1027.1
# 2011-12-28  2011     12   28    20       4        44.0   5.0  71.07  1028.1
# 2011-12-28  2011     12   28    21       4        40.0   5.0  71.07  1028.1
# 2011-12-28  2011     12   28    22       4        25.0   6.0  76.18  1028.1
# 2011-12-28  2011     12   28    23       4        28.0   6.0  76.18  1028.1
# 2011-12-29  2011     12   29     0       4        34.0   6.0  76.18  1028.1
# 2011-12-29  2011     12   29     1       4        25.0   5.0  76.01  1028.1
# 2011-12-29  2011     12   29     2       4        27.0   5.0  76.01  1028.1
# 2011-12-29  2011     12   29     3       4        35.0   5.0  81.34  1028.1
#
#             TEMP cbwd   Iws  precipitation  Iprec  day_or_night
# 2011-12-28  11.0   NE   8.0            0.0    0.0             1
# 2011-12-28  11.0   NE   9.0            0.0    0.0             0
# 2011-12-28  10.0   NE  11.0            0.0    0.0             0
# 2011-12-28  10.0   NE  13.0            0.0    0.0             0
# 2011-12-28  10.0   NE  15.0            0.0    0.0             0
# 2011-12-28  10.0   NE  17.0            0.0    0.0             0
# 2011-12-29  10.0   NE  19.0            0.0    0.0             0
# 2011-12-29   9.0   NE  21.0            0.0    0.0             0
# 2011-12-29   9.0   NE  23.0            0.0    0.0             0
# 2011-12-29   8.0   NE  25.0            0.0    0.0             0

# %%
from sklearn import preprocessing
# create the Labelencoder object
le = preprocessing.LabelEncoder()
#convert the categorical columns into numeric
pm_df['cbwd'] = le.fit_transform(pm_df['cbwd'])
pm_df.head(10)
# Out:
#             year  month  day  hour  season  PM_US Post  DEWP   HUMI    PRES  \
# 2011-12-28  2011     12   28    18       4        36.0   4.0  62.00  1027.1
# 2011-12-28  2011     12   28    19       4        41.0   4.0  62.00  1027.1
# 2011-12-28  2011     12   28    20       4        44.0   5.0  71.07  1028.1
# 2011-12-28  2011     12   28    21       4        40.0   5.0  71.07  1028.1
# 2011-12-28  2011     12   28    22       4        25.0   6.0  76.18  1028.1
# 2011-12-28  2011     12   28    23       4        28.0   6.0  76.18  1028.1
# 2011-12-29  2011     12   29     0       4        34.0   6.0  76.18  1028.1
# 2011-12-29  2011     12   29     1       4        25.0   5.0  76.01  1028.1
# 2011-12-29  2011     12   29     2       4        27.0   5.0  76.01  1028.1
# 2011-12-29  2011     12   29     3       4        35.0   5.0  81.34  1028.1
#
#             TEMP  cbwd   Iws  precipitation  Iprec  day_or_night
# 2011-12-28  11.0     0   8.0            0.0    0.0             1
# 2011-12-28  11.0     0   9.0            0.0    0.0             0
# 2011-12-28  10.0     0  11.0            0.0    0.0             0
# 2011-12-28  10.0     0  13.0            0.0    0.0             0
# 2011-12-28  10.0     0  15.0            0.0    0.0             0
# 2011-12-28  10.0     0  17.0            0.0    0.0             0
# 2011-12-29  10.0     0  19.0            0.0    0.0             0
# 2011-12-29   9.0     0  21.0            0.0    0.0             0
# 2011-12-29   9.0     0  23.0            0.0    0.0             0
# 2011-12-29   8.0     0  25.0            0.0    0.0             0

# %%
encoded_value = le.fit_transform(["cv", "NE", "NW", "SE","SW"])
print(encoded_value)
# Out:
# [4 0 1 2 3]

# %%
Q1 = pm_df.quantile(0.25)
Q3 = pm_df.quantile(0.75)
IQR = Q3 - Q1
pm_df = pm_df[~((pm_df < (Q1 - 1.5 * IQR)) |(pm_df > (Q3 + 1.5 * IQR))).any(axis=1)]
pm_df.shape
# Out:
# (24535, 15)

# %%
del pm_df['year']
del pm_df['month']
del pm_df['day']
del pm_df['hour']
pm_df.head(10)
# Out:
#             season  PM_US Post  DEWP   HUMI    PRES  TEMP  cbwd   Iws  \
# 2011-12-28       4        36.0   4.0  62.00  1027.1  11.0     0   8.0
# 2011-12-28       4        41.0   4.0  62.00  1027.1  11.0     0   9.0
# 2011-12-28       4        44.0   5.0  71.07  1028.1  10.0     0  11.0
# 2011-12-28       4        40.0   5.0  71.07  1028.1  10.0     0  13.0
# 2011-12-28       4        25.0   6.0  76.18  1028.1  10.0     0  15.0
# 2011-12-28       4        28.0   6.0  76.18  1028.1  10.0     0  17.0
# 2011-12-29       4        34.0   6.0  76.18  1028.1  10.0     0  19.0
# 2011-12-29       4        25.0   5.0  76.01  1028.1   9.0     0  21.0
# 2011-12-29       4        27.0   5.0  76.01  1028.1   9.0     0  23.0
# 2011-12-29       4        35.0   5.0  81.34  1028.1   8.0     0  25.0
#
#             precipitation  Iprec  day_or_night
# 2011-12-28            0.0    0.0             1
# 2011-12-28            0.0    0.0             0
# 2011-12-28            0.0    0.0             0
# 2011-12-28            0.0    0.0             0
# 2011-12-28            0.0    0.0             0
# 2011-12-28            0.0    0.0             0
# 2011-12-29            0.0    0.0             0
# 2011-12-29            0.0    0.0             0
# 2011-12-29            0.0    0.0             0
# 2011-12-29            0.0    0.0             0

# %%
le = preprocessing.LabelEncoder()
pm_df["PM_US Post"]=le.fit_transform(pm_df["PM_US Post"])# transfer continous to intger
columns = pm_df.columns

x = pm_df[[c for c in columns if c not in ["PM_US Post"]]]  #independent columns
y = pm_df.iloc[:,1]    #target column i.e price range
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(x,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# /home/ubuntu/.local/lib/python3.5/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [0.00798997 0.11787558 0.14743791 0.21472739 0.12290728 0.03763046
#  0.33806816 0.         0.         0.01336325]

# %%
pm_df_reduced=pm_df[[c for c in columns if c not in ["season","day_or_night","Iprec","precipitation"]]]
pm_df_reduced.head(10)
# Out:
#             PM_US Post  DEWP   HUMI    PRES  TEMP  cbwd   Iws
# 2011-12-28          35   4.0  62.00  1027.1  11.0     0   8.0
# 2011-12-28          40   4.0  62.00  1027.1  11.0     0   9.0
# 2011-12-28          43   5.0  71.07  1028.1  10.0     0  11.0
# 2011-12-28          39   5.0  71.07  1028.1  10.0     0  13.0
# 2011-12-28          24   6.0  76.18  1028.1  10.0     0  15.0
# 2011-12-28          27   6.0  76.18  1028.1  10.0     0  17.0
# 2011-12-29          33   6.0  76.18  1028.1  10.0     0  19.0
# 2011-12-29          24   5.0  76.01  1028.1   9.0     0  21.0
# 2011-12-29          26   5.0  76.01  1028.1   9.0     0  23.0
# 2011-12-29          34   5.0  81.34  1028.1   8.0     0  25.0

# %%
import numpy as np
pm_df_reduced = pm_df_reduced[pm_df_reduced["PM_US Post"] != 0] #remove 0 value in order to use log function
pm_df_reduced['PM_US Post']=np.log(pm_df_reduced['PM_US Post']) # log it
pm_df_reduced.head(10)
# Out:
#             PM_US Post  DEWP   HUMI    PRES  TEMP  cbwd   Iws
# 2011-12-28    3.555348   4.0  62.00  1027.1  11.0     0   8.0
# 2011-12-28    3.688879   4.0  62.00  1027.1  11.0     0   9.0
# 2011-12-28    3.761200   5.0  71.07  1028.1  10.0     0  11.0
# 2011-12-28    3.663562   5.0  71.07  1028.1  10.0     0  13.0
# 2011-12-28    3.178054   6.0  76.18  1028.1  10.0     0  15.0
# 2011-12-28    3.295837   6.0  76.18  1028.1  10.0     0  17.0
# 2011-12-29    3.496508   6.0  76.18  1028.1  10.0     0  19.0
# 2011-12-29    3.178054   5.0  76.01  1028.1   9.0     0  21.0
# 2011-12-29    3.258097   5.0  76.01  1028.1   9.0     0  23.0
# 2011-12-29    3.526361   5.0  81.34  1028.1   8.0     0  25.0

# %%
pm_df_final = pm_df_reduced

# %%
sns.set_style('darkgrid')
sns.distplot(pm_df_final['PM_US Post'])

# %%
#Linear regression model
from pyspark.sql import SparkSession
spark = SparkSession \
        .builder \
        .appName("Python Spark SQL Hive integration example") \
        .enableHiveSupport() \
        .getOrCreate()
sparkDF = spark.createDataFrame(pm_df_final)
sparkDF.show()
# Out:
# +------------------+----+-----+------+----+----+----+
# |        PM_US Post|DEWP| HUMI|  PRES|TEMP|cbwd| Iws|
# +------------------+----+-----+------+----+----+----+
# |3.5553480614894135| 4.0| 62.0|1027.1|11.0|   0| 8.0|
# |3.6888794541139363| 4.0| 62.0|1027.1|11.0|   0| 9.0|
# |3.7612001156935624| 5.0|71.07|1028.1|10.0|   0|11.0|
# |3.6635616461296463| 5.0|71.07|1028.1|10.0|   0|13.0|
# |3.1780538303479458| 6.0|76.18|1028.1|10.0|   0|15.0|
# | 3.295836866004329| 6.0|76.18|1028.1|10.0|   0|17.0|
# |3.4965075614664802| 6.0|76.18|1028.1|10.0|   0|19.0|
# |3.1780538303479458| 5.0|76.01|1028.1| 9.0|   0|21.0|
# | 3.258096538021482| 5.0|76.01|1028.1| 9.0|   0|23.0|
# |3.5263605246161616| 5.0|81.34|1028.1| 8.0|   0|25.0|
# |3.4657359027997265| 5.0|81.34|1027.1| 8.0|   0|29.0|
# |3.4965075614664802| 4.0|70.88|1028.1| 9.0|   0|34.0|
# |3.5553480614894135| 4.0|70.88|1028.1| 9.0|   0|37.0|
# |3.6635616461296463| 4.0|70.88|1029.1| 9.0|   0|40.0|
# |3.6888794541139363| 4.0|70.88|1030.1| 9.0|   0|44.0|
# |3.6635616461296463| 4.0|66.27|1030.1|10.0|   0|49.0|
# |3.6635616461296463| 4.0| 62.0|1030.1|11.0|   0|55.0|
# |3.9512437185814275| 3.0|57.77|1030.1|11.0|   0|61.0|
# |3.6109179126442243| 3.0|57.77|1030.1|11.0|   0|66.0|
# | 3.367295829986474| 1.0|50.08|1029.1|11.0|   0|71.0|
# +------------------+----+-----+------+----+----+----+
# only showing top 20 rows

# %%
sparkDF.printSchema()
# Out:
# root
#  |-- PM_US Post: double (nullable = true)
#  |-- DEWP: double (nullable = true)
#  |-- HUMI: double (nullable = true)
#  |-- PRES: double (nullable = true)
#  |-- TEMP: double (nullable = true)
#  |-- cbwd: long (nullable = true)
#  |-- Iws: double (nullable = true)

# %%
sparkDF.head()
# Out:
# Row(PM_US Post=3.5553480614894135, DEWP=4.0, HUMI=62.0, PRES=1027.1, TEMP=11.0, cbwd=0, Iws=8.0)

# %%
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler
assembler = VectorAssembler(
    inputCols=["DEWP", "HUMI", 
               "PRES","TEMP","cbwd","Iws"],
    outputCol="features")

# %%
output = assembler.transform(sparkDF)

# %%
output.printSchema()
output.head(1)
# Out:
# root
#  |-- PM_US Post: double (nullable = true)
#  |-- DEWP: double (nullable = true)
#  |-- HUMI: double (nullable = true)
#  |-- PRES: double (nullable = true)
#  |-- TEMP: double (nullable = true)
#  |-- cbwd: long (nullable = true)
#  |-- Iws: double (nullable = true)
#  |-- features: vector (nullable = true)
# [Row(PM_US Post=3.5553480614894135, DEWP=4.0, HUMI=62.0, PRES=1027.1, TEMP=11.0, cbwd=0, Iws=8.0, features=DenseVector([4.0, 62.0, 1027.1, 11.0, 0.0, 8.0]))]

# %%
final_data = output.select("features",'PM_US Post')
final_data.show()
# Out:
# +--------------------+------------------+
# |            features|        PM_US Post|
# +--------------------+------------------+
# |[4.0,62.0,1027.1,...|3.5553480614894135|
# |[4.0,62.0,1027.1,...|3.6888794541139363|
# |[5.0,71.07,1028.1...|3.7612001156935624|
# |[5.0,71.07,1028.1...|3.6635616461296463|
# |[6.0,76.18,1028.1...|3.1780538303479458|
# |[6.0,76.18,1028.1...| 3.295836866004329|
# |[6.0,76.18,1028.1...|3.4965075614664802|
# |[5.0,76.01,1028.1...|3.1780538303479458|
# |[5.0,76.01,1028.1...| 3.258096538021482|
# |[5.0,81.34,1028.1...|3.5263605246161616|
# |[5.0,81.34,1027.1...|3.4657359027997265|
# |[4.0,70.88,1028.1...|3.4965075614664802|
# |[4.0,70.88,1028.1...|3.5553480614894135|
# |[4.0,70.88,1029.1...|3.6635616461296463|
# |[4.0,70.88,1030.1...|3.6888794541139363|
# |[4.0,66.27,1030.1...|3.6635616461296463|
# |[4.0,62.0,1030.1,...|3.6635616461296463|
# |[3.0,57.77,1030.1...|3.9512437185814275|
# |[3.0,57.77,1030.1...|3.6109179126442243|
# |[1.0,50.08,1029.1...| 3.367295829986474|
# +--------------------+------------------+
# only showing top 20 rows

# %%
train_data,test_data = final_data.randomSplit([0.8,0.2])

# %%
# Let's see our training data.
train_data.describe().show()

# And our testing data.
test_data.describe().show()
# Out:
# +-------+------------------+
# |summary|        PM_US Post|
# +-------+------------------+
# |  count|             19611|
# |   mean|3.6557363000508163|
# | stddev|0.7035560024973534|
# |    min|               0.0|
# |    max| 4.812184355372417|
# +-------+------------------+
#
# +-------+------------------+
# |summary|        PM_US Post|
# +-------+------------------+
# |  count|              4846|
# |   mean|  3.65503491372226|
# | stddev|0.6922838925816299|
# |    min|               0.0|
# |    max| 4.812184355372417|
# +-------+------------------+

# %%
from pyspark.ml.regression import LinearRegression
lr = LinearRegression(labelCol='PM_US Post')

# %%
lrModel = lr.fit(train_data)

# %%
print("Coefficients: {} Intercept: {}".format(lrModel.coefficients,lrModel.intercept))
# Out:
# Coefficients: [-0.05541952750754952,0.0064390116757693,-0.01814464200337769,0.010757884692695395,0.05474782818810941,-0.003140834665887877] Intercept: 22.123752241910037

# %%
test_results = lrModel.evaluate(test_data)

# %%
# Interesting results! This shows the difference between the predicted value and the test data.
test_results.residuals.show()

# Let's get some evaluation metrics (as discussed in the previous linear regression notebook).
print("RSME: {}".format(test_results.rootMeanSquaredError))
# Out:
# +--------------------+
# |           residuals|
# +--------------------+
# | -0.1441843872388846|
# |-0.40377463510331246|
# |-0.01155555635633...|
# | -0.3101318603234935|
# | 0.14936343827194065|
# |-0.17360019420352923|
# | -0.7180666078522906|
# |-0.07994900027898044|
# |0.026669713741231504|
# |  0.0647306240839347|
# |  0.1550085019678047|
# |-0.14985476132675135|
# |-0.49515671231356473|
# | 0.24880456754911506|
# |  -0.560905497402254|
# |  0.3114649914376013|
# |-0.39876469701376527|
# | -0.2189073811127753|
# |-0.49793947926972537|
# |-0.02644569436585...|
# +--------------------+
# only showing top 20 rows
#
# RSME: 0.6249955389911788

# %%
print("R2: {}".format(test_results.r2))
# Out:
# R2: 0.18477965516557293

# %%
final_data.describe().show()
# Out:
# +-------+------------------+
# |summary|        PM_US Post|
# +-------+------------------+
# |  count|             24457|
# |   mean|3.6555973247820748|
# | stddev|0.7013228913475041|
# |    min|               0.0|
# |    max| 4.812184355372417|
# +-------+------------------+

# %%
predictions = lrModel.transform(test_data)

# %%
predictions.select("features","PM_US Post","prediction").show(5)
# Out:
# +--------------------+------------------+------------------+
# |            features|        PM_US Post|        prediction|
# +--------------------+------------------+------------------+
# |[-14.0,27.36,1029...| 4.394449154672439| 4.538633541911324|
# |[-14.0,29.38,1033...|3.9889840465642745| 4.392758681667587|
# |[-13.0,22.46,1023...|4.2626798770413155| 4.274235433397653|
# |[-13.0,31.88,1029...|  4.30406509320417| 4.614196953527664|
# |[-12.0,26.09,1024...| 4.343805421853684|4.1944419835817435|
# +--------------------+------------------+------------------+
# only showing top 5 rows

# %%
predictions
# Out:
# DataFrame[features: vector, PM_US Post: double, prediction: double]

# %%
test_results

# %%
residuals = test_results.residuals.toPandas()

# %%
sns.distplot(residuals,hist = False)

# %%
import matplotlib.pyplot as plt
df_pre = predictions.toPandas()
preds = df_pre['prediction']
test_target = df_pre['PM_US Post']
plt.figure()
plt.plot(np.arange(len(preds)), test_target,'go-',label='true value')
plt.plot(np.arange(len(preds)),preds,'ro-',label='predict value')
plt.title('R-square: %f'%test_results.r2)
plt.legend()
plt.show()

# %%
y_true = predictions.select("PM_US Post").toPandas()
y_pred = predictions.select("prediction").toPandas()

sns.residplot(y_true,y_pred)
ax.set_title('Residual value of model')

# %%
#Random Forest Model

# %%
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml import Pipeline

# %%
rf = RandomForestRegressor(labelCol='PM_US Post',numTrees=10,maxDepth=10)

rfModel = rf.fit(train_data)

# %%
rfModel.featureImportances
# Out:
# SparseVector(6, {0: 0.2439, 1: 0.0897, 2: 0.1717, 3: 0.1873, 4: 0.1451, 5: 0.1623})

# %%
predictions_rf = rfModel.transform(test_data)

# %%
predictions_rf.select("features","PM_US Post", "prediction").show(5)
# Out:
# +--------------------+------------------+------------------+
# |            features|        PM_US Post|        prediction|
# +--------------------+------------------+------------------+
# |[-14.0,27.36,1029...| 4.394449154672439| 4.061449952243201|
# |[-14.0,29.38,1033...|3.9889840465642745|3.9945135295784753|
# |[-13.0,22.46,1023...|4.2626798770413155| 4.083085020262831|
# |[-13.0,31.88,1029...|  4.30406509320417| 4.165707603714301|
# |[-12.0,26.09,1024...| 4.343805421853684| 4.105652090671929|
# +--------------------+------------------+------------------+
# only showing top 5 rows

# %%
from pyspark.ml.evaluation import RegressionEvaluator
evaluator = RegressionEvaluator(
labelCol="PM_US Post", predictionCol="prediction", metricName="rmse")
rmse = evaluator.evaluate(predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)
# Out:
# Root Mean Squared Error (RMSE) on test data = 0.558419

# %%
import sklearn.metrics
result_rf = predictions.toPandas()
y_pred_rf = result_rf['prediction']
y_true_rf = result_rf['PM_US Post']
r2_score = sklearn.metrics.r2_score(y_true_rf, y_pred_rf)
print('r2_score: {:4.3f}'.format(r2_score))
# Out:
# r2_score: 0.349

# %%
train_data.select("features").show(5)
rfModel.featureImportances
# Out:
# +--------------------+
# |            features|
# +--------------------+
# |[-16.0,24.89,1030...|
# |[-15.0,23.48,1030...|
# |[-15.0,27.05,1029...|
# |[-15.0,27.05,1032...|
# |[-14.0,23.77,1025...|
# +--------------------+
# only showing top 5 rows
# SparseVector(6, {0: 0.2439, 1: 0.0897, 2: 0.1717, 3: 0.1873, 4: 0.1451, 5: 0.1623})

# %%
features=['DEWP','HUMI','PRES','TEMP','cbwd','Iws']
importance=[0.2439,0.0897,0.1717,0.1873,0.1451,0.1623]
ax = sns.barplot(x=features, y=importance)
ax.set_title('Feature Importance')
# Out:
# Text(0.5,1,'Feature Importance')

# %%
import matplotlib.pyplot as plt
df_pre_rf = predictions_rf.toPandas()
preds = df_pre_rf['prediction']
test_target = df_pre_rf['PM_US Post']
plt.figure()
plt.plot(np.arange(len(preds)), test_target,'go-',label='true value')
plt.plot(np.arange(len(preds)),preds,'ro-',label='predict value')
plt.title('R-square: %f'%r2_score)
plt.legend()
plt.show()

# %%
y_true_rf = predictions_rf.select("PM_US Post").toPandas()
y_pred_rf = predictions_rf.select("prediction").toPandas()

sns.residplot(y_true,y_pred)
ax.set_title('Residual value of model')
# Out:
# Text(0.5,1,'Residual value of model')

# %%
#KNN
from sklearn.model_selection import train_test_split
columnss = pm_df_final.columns
input_data=pm_df_final[[c for c in columnss if c not in ['PM_US Post']]]
target=pm_df_final['PM_US Post']
train_input, test_input,train_target,test_target = train_test_split(input_data,target, test_size = 0.20, random_state = 10)

# %%
from sklearn import neighbors
from sklearn.metrics import mean_squared_error
from math import sqrt
knn = neighbors.KNeighborsRegressor()
knn.fit(train_input,train_target)
preds = knn.predict(test_input)
RMSE = sqrt(mean_squared_error(preds,test_target))
print("Root Mean Squared Error (RMSE) on test data = %g" % RMSE)
# Out:
# Root Mean Squared Error (RMSE) on test data = 0.621425

# %%
score_knn=knn.score(test_input,test_target)
print('r2_score: {:4.4f}'.format(score_knn))
# Out:
# r2_score: 0.1796

# %%
plt.figure()
plt.plot(np.arange(len(preds)), test_target,'go-',label='true value')
plt.plot(np.arange(len(preds)),preds,'ro-',label='predict value')
plt.title('score: %f'%score_knn)
plt.legend()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy

sns.residplot(test_target, preds)

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

dfSample = pm_df_final.sample(1000)

sns.set_style('darkgrid')
sns.regplot(x="PM_US Post", y="DEWP", data=dfSample);

# %%
sns.relplot(x="PM_US Post", y="Iws",kind="line", data=dfSample)

# %%
sns.relplot(x="PM_US Post", y="DEWP", hue="cbwd", kind="line", data=dfSample)

# %%
sns.set(style="darkgrid")

g = sns.jointplot("PM_US Post", "PRES", data=dfSample, kind="reg",color="m", height=7)

# %%
sns.catplot(x="cbwd", y="PM_US Post", jitter = False,data=dfSample)

# %%
sns.heatmap(dfSample)

# %%
sns.regplot(x="cbwd", y="PM_US Post", data=dfSample)

# %%
sns.regplot(x="TEMP", y="PM_US Post", data=dfSample)

# %%
sns.distplot(pm_df_final["PM_US Post"])

# %%
column = pm_df_final.columns
pair_df = pm_df_final[[c for c in columnss if c not in ['Iprec','precipitation','HUMI']]]

sns.pairplot(pair_df)
